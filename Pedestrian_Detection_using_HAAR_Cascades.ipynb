# %% [markdown]
# <a href="https://colab.research.google.com/github/PrimalChaos100/Pedestrian-Detection/blob/master/Pedestrian_Detection_using_HAAR_Cascades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload

# %%
from google.colab.patches import cv2_imshow
# load the library using the import keyword
# OpenCV must be properly installed for this to work. If not, then the module will not load with an
# error message.

import cv2
#import sys

# Gets the name of the image file (filename) from sys.argv

image = cv2.imread('test6.jpg')
cascPath = "haarcascade_pedestrian.xml"
cascPath2 = "haarcascade_fullbody.xml"

# This creates the cascade classifcation from file 

pedCascade = cv2.CascadeClassifier(cascPath)
pedCascade2 = cv2.CascadeClassifier(cascPath2)

# The image is read and converted to grayscale

image2 = image.copy()
gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)


# The face or faces in an image are detected
# This section requires the most adjustments to get accuracy on face being detected.


faces = pedCascade.detectMultiScale(
    gray,
    scaleFactor=1.35,
    minNeighbors=9,
    minSize=(10,10),
    flags = cv2.CASCADE_SCALE_IMAGE
)

print("Detected {0} people!".format(len(faces)))

# This draws a green rectangle around the faces detected


for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (50, 50, 255), 2)

cv2_imshow(image)
cv2.waitKey(0)
# Out:
# Detected 7 people!
# <PIL.Image.Image image mode=RGB size=1333x939 at 0x7F134B11CE10>
# -1
